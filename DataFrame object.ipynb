# %%
import pandas as pd

s = pd.DataFrame({"Name":['Sugat','Manish', 'Sagar','Ayush','Sameer','Shubham','Pranay', 'Pranay'], "Surname":['Moon','Ingole','Meshram','Moon','Waghamare','Dhale','Nagrale','Hate']})

# %%
s1 = pd.read_csv('TravelApprovals.csv')

s1
# Out:
#                                             Department Destination State  \
# 0                   Office of Communications and Media                FL
# 1                      Disability Determination Bureau                OK
# 2    Division of Disability and Rehabilitative Serv...                OK
# 3                                           Technology                FL
# 4                                      Human Resources                FL
# ..                                                 ...               ...
# 295                                Division of Finance                GA
# 296                                Contract Management                CA
# 297                          Office of General Counsel                TX
# 298            Division of Mental Health and Addiction                OK
# 299                                Contract Management                GA
#
#                       Purpose of Trip Trip Start Date Trip End Date    Status
# ...

# %%
s1.head()
# Out:
#                                           Department Destination State  \
# 0                 Office of Communications and Media                FL
# 1                    Disability Determination Bureau                OK
# 2  Division of Disability and Rehabilitative Serv...                OK
# 3                                         Technology                FL
# 4                                    Human Resources                FL
#
#                     Purpose of Trip Trip Start Date Trip End Date    Status
# 0                       White-Kutch         6/14/19       6/15/19  Approved
# 1  Runolfsson, Bogisich and DuBuque         10/1/19       10/1/19  Approved
# 2   Homenick, Waters and Gusikowski          4/3/19        4/6/19  Rejected
# 3      Schoen, Mitchell and Kovacek         3/13/19       3/20/19  Approved
# 4                     Senger-Schumm         4/27/19        5/5/19  Approved

# %%
s1.tail()
# Out:
#                                   Department Destination State  \
# 295                      Division of Finance                GA
# 296                      Contract Management                CA
# 297                Office of General Counsel                TX
# 298  Division of Mental Health and Addiction                OK
# 299                      Contract Management                GA
#
#                       Purpose of Trip Trip Start Date Trip End Date    Status
# 295             Cremin, Batz and Huel         3/30/19        4/5/19  Approved
# 296         Cormier, Hayes and Jacobi         6/17/19       6/20/19  Approved
# 297                Altenwerth-Kuhlman        12/22/19      12/28/19  Approved
# 298  Treutel, Tremblay and Swaniawski         3/24/19       3/25/19  Approved
# 299                         Berge Inc        10/30/19       11/2/19  Approved

# %%
s.shape, s1.shape
# Out:
# ((8, 2), (300, 6))

# %%
s1.loc[:5,("Department","Status")]
# Out:
#                                           Department    Status
# 0                 Office of Communications and Media  Approved
# 1                    Disability Determination Bureau  Approved
# 2  Division of Disability and Rehabilitative Serv...  Rejected
# 3                                         Technology  Approved
# 4                                    Human Resources  Approved
# 5                                Division of Finance  Rejected

# %%
s3 = s1.iloc[3:50,:6]

# %%
s3.drop([4,6],axis=0)
# Out:
#                                            Department Destination State  \
# 3                                          Technology                FL
# 5                                 Division of Finance                CA
# 7                                   Division of Aging                OK
# 8                                      Audit Services                FL
# 9                                   Division of Aging                GA
# 10                    Disability Determination Bureau                CA
# 11                                         Technology                TX
# 12                          Office of General Counsel                TX
# 13                 Office of Communications and Media                TX
# 14                                  Division of Aging                FL
# 15                               Legislative Services                OK
# 16                                Contract Management                FL
# ...

# %%
s3.describe()
# Out:
#         Department Destination State               Purpose of Trip  \
# count           47                47                            47
# unique          15                 5                            47
# top     Technology                FL  Schoen, Mitchell and Kovacek
# freq             8                14                             1
#
#        Trip Start Date Trip End Date    Status
# count               47            47        47
# unique              45            43         2
# top            11/5/19       4/14/19  Approved
# freq                 2             2        41

# %%
s3.min()
# Out:
# Department                          Audit Services
# Destination State                               CA
# Purpose of Trip      Abernathy, Beatty and Leffler
# Trip Start Date                            1/12/19
# Trip End Date                               1/1/20
# Status                                    Approved
# dtype: object

# %%
s3.max()
# Out:
# Department             Technology
# Destination State              TX
# Purpose of Trip      Wolff-Schumm
# Trip Start Date            9/8/19
# Trip End Date             9/21/19
# Status                   Rejected
# dtype: object
